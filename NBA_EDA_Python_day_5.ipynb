# %% [markdown]
# <a href="https://colab.research.google.com/github/Asiiifa/Data-science-python-/blob/main/NBA(basketball)_EDA_Python_day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
t=pd.read_csv('/content/nba.csv.csv')
t
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
a=t.Position.unique()
a
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
t.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
t.Age.unique ()
# Out:
# array([25., 27., 22., 29., 21., 24., 20., 26., 28., 32., 23., 30., 33.,
#        34., 37., 36., 31., 38., 39., 19., 35., 40.])

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
t.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
t.tail()
# Out:
#              Name       Team  Number Position   Age Height  Weight   College  \
# 452    Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0  Kentucky
# 453  Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0    Butler
# 454     Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0       NaN
# 455  Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0       NaN
# 456   Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0    Kansas
#
#         Salary
# 452  2239800.0
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0

# %%
t.describe ()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
#data cleaning
t1=t.copy()
a=t.drop(columns =['Name','Number'])
a
# Out:
#                Team Position   Age Height  Weight            College  \
# 0    Boston Celtics       PG  25.0    6-2   180.0              Texas
# 1    Boston Celtics       SF  25.0    6-6   235.0          Marquette
# 2    Boston Celtics       SG  27.0    6-5   205.0  Boston University
# 3    Boston Celtics       SG  22.0    6-5   185.0      Georgia State
# 4    Boston Celtics       PF  29.0   6-10   231.0                NaN
# ..              ...      ...   ...    ...     ...                ...
# 452       Utah Jazz       PF  20.0   6-10   234.0           Kentucky
# 453       Utah Jazz       PG  26.0    6-3   203.0             Butler
# 454       Utah Jazz       PG  24.0    6-1   179.0                NaN
# 455       Utah Jazz        C  26.0    7-3   256.0                NaN
# 456       Utah Jazz        C  26.0    7-0   231.0             Kansas
#
#         Salary
# 0    7730337.0
# 1    6796117.0
# 2          NaN
# 3    1148640.0
# 4    5000000.0
# ..         ...
# 452  2239800.0
# ...

# %%
t.sample()
# Out:
#                Name                   Team  Number Position   Age Height  \
# 77  Harrison Barnes  Golden State Warriors    40.0       SF  24.0    6-8
#
#     Weight         College     Salary
# 77   225.0  North Carolina  3873398.0

# %%
t.sample(14)
# Out:
#                          Name                    Team  Number Position   Age  \
# 192           Stanley Johnson         Detroit Pistons     3.0       SF  20.0
# 308                David West       San Antonio Spurs    30.0       PF  35.0
# 431                  Ed Davis  Portland Trail Blazers    17.0        C  27.0
# 35           Cleanthony Early         New York Knicks    11.0       SF  25.0
# 413             Nick Collison   Oklahoma City Thunder     4.0       PF  35.0
# 179          Tristan Thompson     Cleveland Cavaliers    13.0        C  25.0
# 236             Dirk Nowitzki        Dallas Mavericks    41.0       PF  37.0
# 186  Kentavious Caldwell-Pope         Detroit Pistons     5.0       SG  23.0
# 20             Sergey Karasev           Brooklyn Nets    10.0       SG  22.0
# 274            Brandan Wright       Memphis Grizzlies    34.0       PF  28.0
# 120                Nick Young      Los Angeles Lakers     0.0       SF  31.0
# ...

# %%
t.index
# Out:
# RangeIndex(start=0, stop=457, step=1)

# %%
#t.Salary.fillna(method='bfill',inplace=True)
#t

# %%
#var=pd.read_csv(r'https://raw.githubusercontent.com/arangodb/example-datasets/refs/heads/master/Airports/airports.csv')
#var

# %%
t.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
t.count()
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
#handling of missing dat

# %%
t.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
round (t.isnull().sum()/len(t)*100,2)
# Out:
# Name         0.00
# Team         0.00
# Number       0.00
# Position     0.00
# Age          0.00
# Height       0.00
# Weight       0.00
# College     18.38
# Salary       2.41
# dtype: float64

# %%
t[t.Salary . isnull()]
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
#
#      Weight                College  Salary
# ...

# %% [markdown]
# observation :all the player which taller or equal to 6.2Salary data missing .

# %%
def heighttoCenti(data):

  v = data.split('-')

  footcm = int(v[0])*30.48

  inchcm = int(v[1])*2.54

  return footcm + inchcm

t ['Height_cm'] = t .Height.apply(heighttoCenti)
t
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary  Height_cm
# 0                Texas  7730337.0     187.96
# ...

# %%
  t .drop('Height', axis=1)
# Out:
#               Name            Team  Number Position   Age  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   231.0
# ..             ...             ...     ...      ...   ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0   231.0
#
#                College     Salary  Height_cm
# 0                Texas  7730337.0     187.96
# 1            Marquette  6796117.0     198.12
# ...

# %%
t [t .Height_cm >= 188.976]
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College      Salary  Height_cm
# ...

# %%
def lbstoKG(data):

  v = data*0.453592

  return v

t['Weight_kg'] = t.Weight.apply(lbstoKG)

# %%
   t.drop('Weight', axis=1)
# Out:
#               Name            Team  Number Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...             ...     ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0
#
#                College     Salary  Height_cm   Weight_kg
# 0                Texas  7730337.0     187.96   81.646560
# 1            Marquette  6796117.0     198.12  106.594120
# ...

# %%
def lbstoKG(data):
  v = data * 0.453592
  return v

t['Weight_kg'] = t.Weight.apply(lbstoKG)
t = t.drop('Weight', axis=1)
t
# Out:
#               Name            Team  Number Position   Age Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10
# ..             ...             ...     ...      ...   ...    ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0
#
#                College     Salary  Height_cm   Weight_kg
# 0                Texas  7730337.0     187.96   81.646560
# 1            Marquette  6796117.0     198.12  106.594120
# ...

# %%
t.Height_cm.unique()
# Out:
# array([187.96, 198.12, 195.58, 208.28, 205.74, 203.2 , 213.36, 193.04,
#        175.26, 200.66, 190.5 , 180.34, 210.82, 220.98, 182.88, 218.44,
#        185.42, 215.9 ])
